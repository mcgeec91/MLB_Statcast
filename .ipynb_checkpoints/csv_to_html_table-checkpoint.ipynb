# %%
import pandas as pd

# Read the csv file in
df = pd.read_csv('2018_mlb_batters.csv')

# %%
pd.set_option('display.max_columns', 500)
df = df.rename(index=str, columns={"batter_name": "Batter Name", "pa": "PA",
                             "bbe": "BBE", "total_hits": "Total Hits",
                             "singles": "Singles", "doubles": "Doubles",
                             "triples": "Triples", "home_runs": "HR",
                             "walks": "BB", "ibb": "IBB",
                             "hit_by_pitch": "HBP", "sb": "SB",
                             "cs": "CS", "total_sacrifices": "Total Sacrifices",
                             "gdp": "GDP", "RC_per_pa": "RC%",
                             "true_baa_bib": "True BABIP", "avg_la": "AVG(LA°)",
                             "SW_SP_PA": "Sw_Sp/PA", "SW_SP_perc": "Sw_Sp/BBE",
                             "SSW_SP_PA": "SSw_Sp/PA", "SSW_SP_perc": "SSw_Sp/BBE",
                             "avg_ev": "AVG(EV)", "max_ev": "MAX(EV)",
                             "avg_hit_distance": "AVG(Hit Distance)", "ld_fb_ev": "AVG(LD/FB EV)",
                             "gb_ev": "AVG(GB EV)", "max_hr_speed": "MAX(HR EV)",
                             "avg_hr_distance": "AVG(HR Distance)", "max_hr_dist": "MAX(HR Distance)",
                             "avg_hr_la": "AVG(HR LA°)", "avg_hr_ev": "AVG(HR EV)",
                             "over_95_ev": "95+ EV", "over_95_perc": "95+ EV/BBE",
                             "over_95_pa": "95+ EV/PA", "barrel_count": "Barrels",
                             "barrel_perc": "Barrels/BBE", "barrel_pa_perc": "Barrels/PA"})

df = df.round({"BAA":3, "BABIP":3, "RC":2, "RC%":3, "OBP":3, "SLG":3, "ISO":3, "True BABIP":3})
df = df.round({"AVG(LA°)":1, "Sw_Sp/PA":3, "Sw_Sp/BBE":3, "SSw_Sp/PA":3, "SSw_Sp/BBE":3, 
               "AVG(EV)":1, "AVG(Hit Distance)":0, "AVG(LD/FB EV)":1,"AVG(GB EV)":1,
              "MAX(HR EV)":1, "AVG(HR Distance)":0, "MAX(HR Distance)":0,"AVG(HR LA°)":1,
              "AVG(HR EV)":1, "95+ EV/BBE":3, "95+ EV/PA":3,"Barrels/BBE":3,"Barrels/PA":3})
df.head()
# Out:
#        full_name   AB   PA  BBE  Total Hits  Singles  Doubles  Triples  HR  \
# 0      A.J. Cole    3    4    3           1        0        0        0   1
# 1     A.J. Ellis  151  183  119          41       32        8        0   1
# 2   A.J. Pollock  413  460  321         106       59       21        5  21
# 3  Aaron Altherr  243  285  154          44       24       11        1   8
# 4    Aaron Hicks  480  581  377         119       71       18        3  27
#
#    BB  IBB  GDP  SB  Total Sacrifices  CS  HBP    BAA  BABIP     RC    RC%  \
# 0   0    0    0   0                 1   0    0  0.333  0.000   1.13  0.282
# 1  25    1    2   0                 5   0    1  0.272  0.348  21.82  0.119
# 2  29    2    6  13                 8   2    8  0.257  0.284  64.85  0.141
# 3  36    0   13   3                 2   2    4  0.181  0.247  22.76  0.080
# 4  89    1    1  11                 8   2    3  0.248  0.264  92.36  0.159
#
#      OBP    SLG    ISO  True BABIP  AVG(LA°)  sw_sp_pa  Sw_Sp/BBE  ssw_sp_pa  \
# 0  0.250  1.333  1.000       0.333      10.3    0.2500      0.333     0.2500
# 1  0.372  0.344  0.073       0.344      10.5    0.2404      0.370     0.1530
# 2  0.315  0.484  0.228       0.330      13.2    0.2326      0.333     0.1500
# 3  0.295  0.333  0.152       0.286      10.4    0.1719      0.318     0.1228
# 4  0.365  0.467  0.219       0.316      12.5    0.2255      0.348     0.1360
#
#    SSw_Sp/BBE  AVG(EV)  MAX(EV)  AVG(LD/FB EV)  AVG(GB EV)  MAX(HR EV)  \
# 0       0.333     67.6    105.2          105.2        41.0       105.2
# 1       0.235     88.6    106.8           93.6        84.2       102.9
# 2       0.215     89.0    108.6           93.7        84.5       108.6
# 3       0.227     90.5    114.6           96.9        87.5       108.5
# 4       0.210     88.9    110.0           93.3        85.1       107.7
#
#    AVG(HR Distance)  MAX(HR Distance)  AVG(HR LA°)  AVG(HR EV)  95+ EV  \
# 0             395.0               395         19.0         6.0       1
# 1             398.0               398         25.0         6.0      46
# 2             405.0               455         28.5         5.7     130
# 3             398.0               421         28.6         6.0      71
# 4             388.0               417         29.4         5.6     162
#
#    95+ EV/BBE  95+ EV/PA  Barrels  Barrels/BBE  Barrels/PA
# 0       0.333      0.250        1        0.333       0.333
# 1       0.387      0.251        4        0.034       0.034
# 2       0.405      0.283       27        0.084       0.084
# 3       0.461      0.249       13        0.084       0.084
# 4       0.430      0.279       31        0.082       0.082

# %%
# Save to file
df.to_html('batters.html')
